# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('income_evaluation.csv')
df
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country  \
# 0         Male           2174              0               40   United-States
# 1         Male              0              0               13   United-States
# 2         Male              0              0               40   United-States
# 3         Male              0              0               40   United-States
# 4       Female              0              0               40            Cuba
# ...        ...            ...            ...              ...             ...
# 32556   Female              0              0               38   United-States
# 32557     Male              0              0               40   United-States
# 32558   Female              0              0               40   United-States
# 32559     Male              0              0               20   United-States
# 32560   Female          15024              0               40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K
#
# [32561 rows x 15 columns]

# %%
df.head()
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#     capital-gain   capital-loss   hours-per-week  native-country  income
# 0           2174              0               40   United-States   <=50K
# 1              0              0               13   United-States   <=50K
# 2              0              0               40   United-States   <=50K
# 3              0              0               40   United-States   <=50K
# 4              0              0               40            Cuba   <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
df[' income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
def zerone(x):
    if x==' <=50K':
        return 0
    else:
        return 1

# %%
df[' income']=df[' income'].apply(zerone)
df
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex   capital-gain   capital-loss   hours-per-week  native-country  \
# 0         Male           2174              0               40   United-States
# 1         Male              0              0               13   United-States
# 2         Male              0              0               40   United-States
# 3         Male              0              0               40   United-States
# 4       Female              0              0               40            Cuba
# ...        ...            ...            ...              ...             ...
# 32556   Female              0              0               38   United-States
# 32557     Male              0              0               40   United-States
# 32558   Female              0              0               40   United-States
# 32559     Male              0              0               20   United-States
# 32560   Female          15024              0               40   United-States
#
#         income
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 32556        0
# 32557        1
# 32558        0
# 32559        0
# 32560        1
#
# [32561 rows x 15 columns]

# %%
df[' income'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.drop(columns=[' race'],inplace=True)

# %%
df
# Out:
#        age          workclass   fnlwgt    education   education-num  \
# 0       39          State-gov    77516    Bachelors              13
# 1       50   Self-emp-not-inc    83311    Bachelors              13
# 2       38            Private   215646      HS-grad               9
# 3       53            Private   234721         11th               7
# 4       28            Private   338409    Bachelors              13
# ...    ...                ...      ...          ...             ...
# 32556   27            Private   257302   Assoc-acdm              12
# 32557   40            Private   154374      HS-grad               9
# 32558   58            Private   151910      HS-grad               9
# 32559   22            Private   201490      HS-grad               9
# 32560   52       Self-emp-inc   287927      HS-grad               9
#
#             marital-status          occupation    relationship      sex  \
# 0            Never-married        Adm-clerical   Not-in-family     Male
# 1       Married-civ-spouse     Exec-managerial         Husband     Male
# 2                 Divorced   Handlers-cleaners   Not-in-family     Male
# 3       Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4       Married-civ-spouse      Prof-specialty            Wife   Female
# ...                    ...                 ...             ...      ...
# 32556   Married-civ-spouse        Tech-support            Wife   Female
# 32557   Married-civ-spouse   Machine-op-inspct         Husband     Male
# 32558              Widowed        Adm-clerical       Unmarried   Female
# 32559        Never-married        Adm-clerical       Own-child     Male
# 32560   Married-civ-spouse     Exec-managerial            Wife   Female
#
#         capital-gain   capital-loss   hours-per-week  native-country   income
# 0               2174              0               40   United-States        0
# 1                  0              0               13   United-States        0
# 2                  0              0               40   United-States        0
# 3                  0              0               40   United-States        0
# 4                  0              0               40            Cuba        0
# ...              ...            ...              ...             ...      ...
# 32556              0              0               38   United-States        0
# 32557              0              0               40   United-States        1
# 32558              0              0               40   United-States        0
# 32559              0              0               20   United-States        0
# 32560          15024              0               40   United-States        1
#
# [32561 rows x 14 columns]

# %%
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#        age   fnlwgt   education-num   capital-gain   capital-loss  \
# 0       39    77516              13           2174              0
# 1       50    83311              13              0              0
# 2       38   215646               9              0              0
# 3       53   234721               7              0              0
# 4       28   338409              13              0              0
# ...    ...      ...             ...            ...            ...
# 32556   27   257302              12              0              0
# 32557   40   154374               9              0              0
# 32558   58   151910               9              0              0
# 32559   22   201490               9              0              0
# 32560   52   287927               9          15024              0
#
#         hours-per-week   income   workclass_ Federal-gov  \
# 0                   40        0                    False
# 1                   13        0                    False
# 2                   40        0                    False
# 3                   40        0                    False
# 4                   40        0                    False
# ...                ...      ...                      ...
# 32556               38        0                    False
# 32557               40        1                    False
# 32558               40        0                    False
# 32559               20        0                    False
# 32560               40        1                    False
#
#         workclass_ Local-gov   workclass_ Never-worked  ...  \
# 0                      False                     False  ...
# 1                      False                     False  ...
# 2                      False                     False  ...
# 3                      False                     False  ...
# 4                      False                     False  ...
# ...                      ...                       ...  ...
# 32556                  False                     False  ...
# 32557                  False                     False  ...
# 32558                  False                     False  ...
# 32559                  False                     False  ...
# 32560                  False                     False  ...
#
#         native-country_ Portugal   native-country_ Puerto-Rico  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 32556                      False                         False
# 32557                      False                         False
# 32558                      False                         False
# 32559                      False                         False
# 32560                      False                         False
#
#         native-country_ Scotland   native-country_ South  \
# 0                          False                   False
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
# ...                          ...                     ...
# 32556                      False                   False
# 32557                      False                   False
# 32558                      False                   False
# 32559                      False                   False
# 32560                      False                   False
#
#         native-country_ Taiwan   native-country_ Thailand  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
# ...                        ...                        ...
# 32556                    False                      False
# 32557                    False                      False
# 32558                    False                      False
# 32559                    False                      False
# 32560                    False                      False
#
#         native-country_ Trinadad&Tobago   native-country_ United-States  \
# 0                                 False                            True
# 1                                 False                            True
# 2                                 False                            True
# 3                                 False                            True
# 4                                 False                           False
# ...                                 ...                             ...
# 32556                             False                            True
# 32557                             False                            True
# 32558                             False                            True
# 32559                             False                            True
# 32560                             False                            True
#
#         native-country_ Vietnam   native-country_ Yugoslavia
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                         False                        False
# 4                         False                        False
# ...                         ...                          ...
# 32556                     False                        False
# 32557                     False                        False
# 32558                     False                        False
# 32559                     False                        False
# 32560                     False                        False
#
# [32561 rows x 97 columns]

# %%
df.corr()
# Out:
#                                        age    fnlwgt   education-num  \
# age                               1.000000 -0.076646        0.036527
#  fnlwgt                          -0.076646  1.000000       -0.043195
#  education-num                    0.036527 -0.043195        1.000000
#  capital-gain                     0.077674  0.000432        0.122630
#  capital-loss                     0.057775 -0.010252        0.079923
# ...                                    ...       ...             ...
#  native-country_ Thailand        -0.006271 -0.001250        0.007896
#  native-country_ Trinadad&Tobago  0.004843  0.005273       -0.017071
#  native-country_ United-States    0.015917 -0.075287        0.101207
#  native-country_ Vietnam         -0.015054 -0.011398       -0.007483
#  native-country_ Yugoslavia       0.000375  0.005501       -0.001234
#
#                                    capital-gain   capital-loss  \
# age                                    0.077674   5.777454e-02
#  fnlwgt                                0.000432  -1.025171e-02
#  education-num                         0.122630   7.992296e-02
#  capital-gain                          1.000000  -3.161506e-02
#  capital-loss                         -0.031615   1.000000e+00
# ...                                         ...            ...
#  native-country_ Thailand             -0.003432  -5.095482e-03
#  native-country_ Trinadad&Tobago      -0.003526   8.102329e-03
#  native-country_ United-States         0.004599   8.783567e-03
#  native-country_ Vietnam              -0.002564  -5.997599e-07
#  native-country_ Yugoslavia           -0.002193  -4.803919e-03
#
#                                    hours-per-week    income  \
# age                                      0.068756  0.234037
#  fnlwgt                                 -0.018768 -0.009463
#  education-num                           0.148123  0.335154
#  capital-gain                            0.078409  0.223329
#  capital-loss                            0.054256  0.150526
# ...                                           ...       ...
#  native-country_ Thailand                0.009537 -0.004078
#  native-country_ Trinadad&Tobago        -0.006006 -0.007660
#  native-country_ United-States           0.002446  0.034470
#  native-country_ Vietnam                -0.011379 -0.017649
#  native-country_ Yugoslavia              0.007408  0.006959
#
#                                    workclass_ Federal-gov  \
# age                                              0.051227
#  fnlwgt                                         -0.007525
#  education-num                                   0.060518
#  capital-gain                                   -0.005768
#  capital-loss                                    0.010798
# ...                                                   ...
#  native-country_ Thailand                       -0.004099
#  native-country_ Trinadad&Tobago                -0.004212
#  native-country_ United-States                   0.015441
#  native-country_ Vietnam                         0.000099
#  native-country_ Yugoslavia                     -0.003865
#
#                                    workclass_ Local-gov  \
# age                                            0.060901
#  fnlwgt                                       -0.002828
#  education-num                                 0.097941
#  capital-gain                                 -0.007007
#  capital-loss                                  0.014668
# ...                                                 ...
#  native-country_ Thailand                     -0.006164
#  native-country_ Trinadad&Tobago              -0.001148
#  native-country_ United-States                 0.033196
#  native-country_ Vietnam                      -0.003611
#  native-country_ Yugoslavia                   -0.000161
#
#                                    workclass_ Never-worked  ...  \
# age                                              -0.019362  ...
#  fnlwgt                                           0.005031  ...
#  education-num                                   -0.015117  ...
#  capital-gain                                    -0.002140  ...
#  capital-loss                                    -0.003177  ...
# ...                                                    ...  ...
#  native-country_ Thailand                        -0.000345  ...
#  native-country_ Trinadad&Tobago                 -0.000354  ...
#  native-country_ United-States                    0.005000  ...
#  native-country_ Vietnam                         -0.000666  ...
#  native-country_ Yugoslavia                      -0.000325  ...
#
#                                    native-country_ Portugal  \
# age                                                0.004242
#  fnlwgt                                           -0.013152
#  education-num                                    -0.044286
#  capital-gain                                     -0.003879
#  capital-loss                                     -0.007308
# ...                                                     ...
#  native-country_ Thailand                         -0.000793
#  native-country_ Trinadad&Tobago                  -0.000815
#  native-country_ United-States                    -0.098924
#  native-country_ Vietnam                          -0.001532
#  native-country_ Yugoslavia                       -0.000748
#
#                                    native-country_ Puerto-Rico  \
# age                                                   0.008374
#  fnlwgt                                               0.007164
#  education-num                                       -0.041269
#  capital-gain                                        -0.006103
#  capital-loss                                        -0.004718
# ...                                                        ...
#  native-country_ Thailand                            -0.001394
#  native-country_ Trinadad&Tobago                     -0.001432
#  native-country_ United-States                       -0.173848
#  native-country_ Vietnam                             -0.002692
#  native-country_ Yugoslavia                          -0.001314
#
#                                    native-country_ Scotland  \
# age                                                0.002583
#  fnlwgt                                           -0.003790
#  education-num                                     0.001264
#  capital-gain                                     -0.001680
#  capital-loss                                     -0.004160
# ...                                                     ...
#  native-country_ Thailand                         -0.000452
#  native-country_ Trinadad&Tobago                  -0.000464
#  native-country_ United-States                    -0.056315
#  native-country_ Vietnam                          -0.000872
#  native-country_ Yugoslavia                       -0.000426
#
#                                    native-country_ South  \
# age                                             0.000613
#  fnlwgt                                        -0.012365
#  education-num                                  0.016046
#  capital-gain                                   0.005323
#  capital-loss                                   0.010114
# ...                                                  ...
#  native-country_ Thailand                      -0.001167
#  native-country_ Trinadad&Tobago               -0.001199
#  native-country_ United-States                 -0.145558
#  native-country_ Vietnam                       -0.002254
#  native-country_ Yugoslavia                    -0.001100
#
#                                    native-country_ Taiwan  \
# age                                             -0.013816
#  fnlwgt                                         -0.001252
#  education-num                                   0.049472
#  capital-gain                                    0.005735
#  capital-loss                                    0.006637
# ...                                                   ...
#  native-country_ Thailand                       -0.000932
#  native-country_ Trinadad&Tobago                -0.000957
#  native-country_ United-States                  -0.116167
#  native-country_ Vietnam                        -0.001799
#  native-country_ Yugoslavia                     -0.000878
#
#                                    native-country_ Thailand  \
# age                                               -0.006271
#  fnlwgt                                           -0.001250
#  education-num                                     0.007896
#  capital-gain                                     -0.003432
#  capital-loss                                     -0.005095
# ...                                                     ...
#  native-country_ Thailand                          1.000000
#  native-country_ Trinadad&Tobago                  -0.000568
#  native-country_ United-States                    -0.068978
#  native-country_ Vietnam                          -0.001068
#  native-country_ Yugoslavia                       -0.000521
#
#                                    native-country_ Trinadad&Tobago  \
# age                                                       0.004843
#  fnlwgt                                                   0.005273
#  education-num                                           -0.017071
#  capital-gain                                            -0.003526
#  capital-loss                                             0.008102
# ...                                                            ...
#  native-country_ Thailand                                -0.000568
#  native-country_ Trinadad&Tobago                          1.000000
#  native-country_ United-States                           -0.070869
#  native-country_ Vietnam                                 -0.001097
#  native-country_ Yugoslavia                              -0.000536
#
#                                    native-country_ United-States  \
# age                                                     0.015917
#  fnlwgt                                                -0.075287
#  education-num                                          0.101207
#  capital-gain                                           0.004599
#  capital-loss                                           0.008784
# ...                                                          ...
#  native-country_ Thailand                              -0.068978
#  native-country_ Trinadad&Tobago                       -0.070869
#  native-country_ United-States                          1.000000
#  native-country_ Vietnam                               -0.133180
#  native-country_ Yugoslavia                            -0.065031
#
#                                    native-country_ Vietnam  \
# age                                          -1.505357e-02
#  fnlwgt                                      -1.139827e-02
#  education-num                               -7.483035e-03
#  capital-gain                                -2.564276e-03
#  capital-loss                                -5.997599e-07
# ...                                                    ...
#  native-country_ Thailand                    -1.067931e-03
#  native-country_ Trinadad&Tobago             -1.097212e-03
#  native-country_ United-States               -1.331803e-01
#  native-country_ Vietnam                      1.000000e+00
#  native-country_ Yugoslavia                  -1.006824e-03
#
#                                    native-country_ Yugoslavia
# age                                                  0.000375
#  fnlwgt                                              0.005501
#  education-num                                      -0.001234
#  capital-gain                                       -0.002193
#  capital-loss                                       -0.004804
# ...                                                       ...
#  native-country_ Thailand                           -0.000521
#  native-country_ Trinadad&Tobago                    -0.000536
#  native-country_ United-States                      -0.065031
#  native-country_ Vietnam                            -0.001007
#  native-country_ Yugoslavia                          1.000000
#
# [97 rows x 97 columns]

# %%
numerical_df = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
x=df.drop(columns=[' income'])
x
# Out:
#        age   fnlwgt   education-num   capital-gain   capital-loss  \
# 0       39    77516              13           2174              0
# 1       50    83311              13              0              0
# 2       38   215646               9              0              0
# 3       53   234721               7              0              0
# 4       28   338409              13              0              0
# ...    ...      ...             ...            ...            ...
# 32556   27   257302              12              0              0
# 32557   40   154374               9              0              0
# 32558   58   151910               9              0              0
# 32559   22   201490               9              0              0
# 32560   52   287927               9          15024              0
#
#         hours-per-week   workclass_ Federal-gov   workclass_ Local-gov  \
# 0                   40                    False                  False
# 1                   13                    False                  False
# 2                   40                    False                  False
# 3                   40                    False                  False
# 4                   40                    False                  False
# ...                ...                      ...                    ...
# 32556               38                    False                  False
# 32557               40                    False                  False
# 32558               40                    False                  False
# 32559               20                    False                  False
# 32560               40                    False                  False
#
#         workclass_ Never-worked   workclass_ Private  ...  \
# 0                         False                False  ...
# 1                         False                False  ...
# 2                         False                 True  ...
# 3                         False                 True  ...
# 4                         False                 True  ...
# ...                         ...                  ...  ...
# 32556                     False                 True  ...
# 32557                     False                 True  ...
# 32558                     False                 True  ...
# 32559                     False                 True  ...
# 32560                     False                False  ...
#
#         native-country_ Portugal   native-country_ Puerto-Rico  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
# ...                          ...                           ...
# 32556                      False                         False
# 32557                      False                         False
# 32558                      False                         False
# 32559                      False                         False
# 32560                      False                         False
#
#         native-country_ Scotland   native-country_ South  \
# 0                          False                   False
# 1                          False                   False
# 2                          False                   False
# 3                          False                   False
# 4                          False                   False
# ...                          ...                     ...
# 32556                      False                   False
# 32557                      False                   False
# 32558                      False                   False
# 32559                      False                   False
# 32560                      False                   False
#
#         native-country_ Taiwan   native-country_ Thailand  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
# ...                        ...                        ...
# 32556                    False                      False
# 32557                    False                      False
# 32558                    False                      False
# 32559                    False                      False
# 32560                    False                      False
#
#         native-country_ Trinadad&Tobago   native-country_ United-States  \
# 0                                 False                            True
# 1                                 False                            True
# 2                                 False                            True
# 3                                 False                            True
# 4                                 False                           False
# ...                                 ...                             ...
# 32556                             False                            True
# 32557                             False                            True
# 32558                             False                            True
# 32559                             False                            True
# 32560                             False                            True
#
#         native-country_ Vietnam   native-country_ Yugoslavia
# 0                         False                        False
# 1                         False                        False
# 2                         False                        False
# 3                         False                        False
# 4                         False                        False
# ...                         ...                          ...
# 32556                     False                        False
# 32557                     False                        False
# 32558                     False                        False
# 32559                     False                        False
# 32560                     False                        False
#
# [32561 rows x 96 columns]

# %%
y=df[' income']
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name:  income, Length: 32561, dtype: int64

# %%
x.shape
# Out:
# (32561, 96)

# %%
y.shape
# Out:
# (32561,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[ 0.03067056, -1.06361075,  1.13473876, ...,  0.34095391,
#         -0.04540836, -0.02217266],
#        [ 0.83710898, -1.008707  ,  1.13473876, ...,  0.34095391,
#         -0.04540836, -0.02217266],
#        [-0.04264203,  0.2450785 , -0.42005962, ...,  0.34095391,
#         -0.04540836, -0.02217266],
#        ...,
#        [ 1.42360965, -0.35877741, -0.42005962, ...,  0.34095391,
#         -0.04540836, -0.02217266],
#        [-1.21564337,  0.11095988, -0.42005962, ...,  0.34095391,
#         -0.04540836, -0.02217266],
#        [ 0.98373415,  0.92989258, -0.42005962, ...,  0.34095391,
#         -0.04540836, -0.02217266]])

# %%
df=pd.DataFrame(x_scaled,columns=x.columns)
df
# Out:
#             age    fnlwgt   education-num   capital-gain   capital-loss  \
# 0      0.030671 -1.063611        1.134739       0.148453       -0.21666
# 1      0.837109 -1.008707        1.134739      -0.145920       -0.21666
# 2     -0.042642  0.245079       -0.420060      -0.145920       -0.21666
# 3      1.057047  0.425801       -1.197459      -0.145920       -0.21666
# 4     -0.775768  1.408176        1.134739      -0.145920       -0.21666
# ...         ...       ...             ...            ...            ...
# 32556 -0.849080  0.639741        0.746039      -0.145920       -0.21666
# 32557  0.103983 -0.335433       -0.420060      -0.145920       -0.21666
# 32558  1.423610 -0.358777       -0.420060      -0.145920       -0.21666
# 32559 -1.215643  0.110960       -0.420060      -0.145920       -0.21666
# 32560  0.983734  0.929893       -0.420060       1.888424       -0.21666
#
#         hours-per-week   workclass_ Federal-gov   workclass_ Local-gov  \
# 0            -0.035429                -0.174295              -0.262097
# 1            -2.222153                -0.174295              -0.262097
# 2            -0.035429                -0.174295              -0.262097
# 3            -0.035429                -0.174295              -0.262097
# 4            -0.035429                -0.174295              -0.262097
# ...                ...                      ...                    ...
# 32556        -0.197409                -0.174295              -0.262097
# 32557        -0.035429                -0.174295              -0.262097
# 32558        -0.035429                -0.174295              -0.262097
# 32559        -1.655225                -0.174295              -0.262097
# 32560        -0.035429                -0.174295              -0.262097
#
#         workclass_ Never-worked   workclass_ Private  ...  \
# 0                     -0.014664            -1.516792  ...
# 1                     -0.014664            -1.516792  ...
# 2                     -0.014664             0.659286  ...
# 3                     -0.014664             0.659286  ...
# 4                     -0.014664             0.659286  ...
# ...                         ...                  ...  ...
# 32556                 -0.014664             0.659286  ...
# 32557                 -0.014664             0.659286  ...
# 32558                 -0.014664             0.659286  ...
# 32559                 -0.014664             0.659286  ...
# 32560                 -0.014664            -1.516792  ...
#
#         native-country_ Portugal   native-country_ Puerto-Rico  \
# 0                      -0.033729                     -0.059274
# 1                      -0.033729                     -0.059274
# 2                      -0.033729                     -0.059274
# 3                      -0.033729                     -0.059274
# 4                      -0.033729                     -0.059274
# ...                          ...                           ...
# 32556                  -0.033729                     -0.059274
# 32557                  -0.033729                     -0.059274
# 32558                  -0.033729                     -0.059274
# 32559                  -0.033729                     -0.059274
# 32560                  -0.033729                     -0.059274
#
#         native-country_ Scotland   native-country_ South  \
# 0                      -0.019201               -0.049628
# 1                      -0.019201               -0.049628
# 2                      -0.019201               -0.049628
# 3                      -0.019201               -0.049628
# 4                      -0.019201               -0.049628
# ...                          ...                     ...
# 32556                  -0.019201               -0.049628
# 32557                  -0.019201               -0.049628
# 32558                  -0.019201               -0.049628
# 32559                  -0.019201               -0.049628
# 32560                  -0.019201               -0.049628
#
#         native-country_ Taiwan   native-country_ Thailand  \
# 0                    -0.039607                  -0.023518
# 1                    -0.039607                  -0.023518
# 2                    -0.039607                  -0.023518
# 3                    -0.039607                  -0.023518
# 4                    -0.039607                  -0.023518
# ...                        ...                        ...
# 32556                -0.039607                  -0.023518
# 32557                -0.039607                  -0.023518
# 32558                -0.039607                  -0.023518
# 32559                -0.039607                  -0.023518
# 32560                -0.039607                  -0.023518
#
#         native-country_ Trinadad&Tobago   native-country_ United-States  \
# 0                             -0.024163                        0.340954
# 1                             -0.024163                        0.340954
# 2                             -0.024163                        0.340954
# 3                             -0.024163                        0.340954
# 4                             -0.024163                       -2.932948
# ...                                 ...                             ...
# 32556                         -0.024163                        0.340954
# 32557                         -0.024163                        0.340954
# 32558                         -0.024163                        0.340954
# 32559                         -0.024163                        0.340954
# 32560                         -0.024163                        0.340954
#
#         native-country_ Vietnam   native-country_ Yugoslavia
# 0                     -0.045408                    -0.022173
# 1                     -0.045408                    -0.022173
# 2                     -0.045408                    -0.022173
# 3                     -0.045408                    -0.022173
# 4                     -0.045408                    -0.022173
# ...                         ...                          ...
# 32556                 -0.045408                    -0.022173
# 32557                 -0.045408                    -0.022173
# 32558                 -0.045408                    -0.022173
# 32559                 -0.045408                    -0.022173
# 32560                 -0.045408                    -0.022173
#
# [32561 rows x 96 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
x_train.size
# Out:
# 1562880

# %%
y_train.size
# Out:
# 16280

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(x_train,y_train)
# Out:
# 0.7977272727272727

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import  accuracy_score,confusion_matrix, classification_report

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7904919845218352

# %%
c=confusion_matrix(y_test,y_pred) #yaxis actual value in plot and x axis predcted value

# %%
sns.heatmap(c,annot=True,fmt=".1f")
plt.show()

# %%
classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.81      0.95      0.87     12350\n           1       0.64      0.30      0.41      3931\n\n    accuracy                           0.79     16281\n   macro avg       0.72      0.62      0.64     16281\nweighted avg       0.77      0.79      0.76     16281\n'
